# %%
import numpy as np
import graphics
import rover

def forward_backward(all_possible_hidden_states,
                     all_possible_observed_states,
                     prior_distribution,
                     transition_model,
                     observation_model,
                     observations):
    """
    Inputs
    ------
    all_possible_hidden_states: a list of possible hidden states
    all_possible_observed_states: a list of possible observed states
    prior_distribution: a distribution over states

    transition_model: a function that takes a hidden state and returns a
        Distribution for the next state
    observation_model: a function that takes a hidden state and returns a
        Distribution for the observation from that hidden state
    observations: a list of observations, one per hidden state
        (a missing observation is encoded as None)

    Output
    ------
    A list of marginal distributions at each time step; each distribution
    should be encoded as a Distribution (see the Distribution class in
    rover.py), and the i-th Distribution should correspond to time
    step i
    """

    num_time_steps = len(hidden_states)
    forward_messages = [None] * num_time_steps
    forward_messages[0] = prior_distribution
    backward_messages = [None] * num_time_steps
    marginals = [None] * num_time_steps

    # Initialization
    backward_messages[num_time_steps - 1] = rover.Distribution()

    for z in all_possible_hidden_states:
        backward_messages[num_time_steps - 1][z] = 1


    # TODO: Compute the forward messages
    for i in range(1, num_time_steps):
        Xi = observations[i]
        forward_messages[i] = rover.Distribution()

        for zi in all_possible_hidden_states:
            if Xi is None:
                Xi_given_zi = 1

            else:
                Xi_given_zi = rover.observation_model(zi)[Xi]

            sum = 0
            for z, prev in forward_messages[i-1].items():
                factor = rover.transition_model(z)[zi]
                sum = sum + prev * factor * Xi_given_zi

            if sum == 0:
                continue

            forward_messages[i][zi] = sum

        forward_messages[i].renormalize()


    # TODO: Compute the backward messages
    for i in range(num_time_steps - 1, 0, -1):
        backward_messages[i-1] = rover.Distribution()
        Xi = observations[i]

        for zi in all_possible_hidden_states:

            sum = 0
            for z, next in backward_messages[i].items():

                if Xi is None:
                    Xi_given_zi = 1

                else:
                    Xi_given_zi = rover.observation_model(z)[Xi]

                factor = rover.transition_model(zi)[z]
                sum = sum + next * factor * Xi_given_zi

            if sum == 0:
                continue

            backward_messages[i-1][zi] = sum

        backward_messages[i-1].renormalize()

    # TODO: Compute the marginals
    for i in range(num_time_steps):
        marginals[i] = rover.Distribution()
        sum = 0

        for z in all_possible_hidden_states:
            alpha_i = forward_messages[i][z]
            beta_i = backward_messages[i][z]

            if alpha_i * beta_i != 0:
                marginals[i][z] = alpha_i * beta_i
            sum = sum + alpha_i * beta_i

        if sum != 0:
            for state in marginals[i].keys():
                marginals[i][state] = marginals[i][state] / sum

    return marginals

def Viterbi(all_possible_hidden_states,
            all_possible_observed_states,
            prior_distribution,
            transition_model,
            observation_model,
            observations):
    """
    Inputs
    ------
    See the list inputs for the function forward_backward() above.

    Output
    ------
    A list of esitmated hidden states, each state is encoded as a tuple
    (<x>, <y>, <action>)
    """
    num_time_steps = len(observations)
    w = [None] * num_time_steps
    max_prev_path = [None] * num_time_steps
    estimated_hidden_states = [None] * num_time_steps


    for i in range(num_time_steps):
        w[i] = rover.Distribution()
        max_prev_path[i] = rover.Distribution()

    for zi, prob in prior_distribution.items():
        X0_given_z0 = prior_distribution[zi]

        pcond_X0_z0 = observation_model(zi)[observations[0]]
        if X0_given_z0 * prob == 0:
            continue
        w[0][zi] = np.log(prob) + np.log(pcond_X0_z0)

    for i in range(1, num_time_steps):
        xi = observations[i]
        
        for zi in all_possible_hidden_states:
            if xi is None:
                Xi_given_zi = 1
            else:
                Xi_given_zi = observation_model(zi)[xi]

            if Xi_given_zi == 0:
                continue
                
            max_prev = np.NINF
            for z, prev in w[i - 1].items():
                
                zi_given_prev = transition_model(z)[zi]
                if zi_given_prev == 0:
                    continue
                    
                new_prev = np.log(zi_given_prev) + prev
                if new_prev > max_prev:
                    max_prev = new_prev
                    max_prev_path[i][zi] = z
            w[i][zi] = np.log(Xi_given_zi) + max_prev


    estimate_zN = None
    for zi, max_zi in w[num_time_steps - 1].items():
        max_prob = np.NINF
        if max_zi > max_prob:
            max_prob = max_zi
            estimate_zN = zi
    estimated_hidden_states[num_time_steps - 1] = estimate_zN

    for i in range(num_time_steps-2, -1, -1):
        estimated_hidden_states[i] = max_prev_path[i + 1][estimated_hidden_states[i + 1]]

    return estimated_hidden_states



if __name__ == '__main__':

    enable_graphics = False

    missing_observations = True
    if missing_observations:
        filename = 'test_missing.txt'
    else:
        filename = 'test.txt'

    # load data
    hidden_states, observations = rover.load_data(filename)
    num_time_steps = len(hidden_states)

    all_possible_hidden_states   = rover.get_all_hidden_states()
    all_possible_observed_states = rover.get_all_observed_states()
    prior_distribution           = rover.initial_distribution()

    print('Running forward-backward...')
    marginals = forward_backward(all_possible_hidden_states,
                                 all_possible_observed_states,
                                 prior_distribution,
                                 rover.transition_model,
                                 rover.observation_model,
                                 observations)
    print('\n')


    for timestep in range(num_time_steps):
        print("Most likely parts of marginal at time %d:" % (timestep))
        print(sorted(marginals[timestep].items(), key=lambda x: x[1], reverse=True)[:10])
        print('\n')

    print('Running Viterbi...')
    estimated_states = Viterbi(all_possible_hidden_states,
                               all_possible_observed_states,
                               prior_distribution,
                               rover.transition_model,
                               rover.observation_model,
                               observations)
    print('\n')

    print("Last 10 hidden states in the MAP estimate:")
    for time_step in range(num_time_steps - 10, num_time_steps):
        print(estimated_states[time_step])
        
    print("Calculating error rate...")    
    error_fb = 0
    error_vi = 0
        
    for i in range(num_time_steps):
        
        max_prob = 0
        fb_estimate = None
        for state, prob in marginals[i].items():
            if prob > max_prob:
                fb_estimate = state
                max_prob = prob
                
        print(i)
        print('fb:{}'.format(fb_estimate))
        print('map:{}'.format(estimated_states[i]))
        print('real:{}'.format(hidden_states[i]))
        
        if fb_estimate != hidden_states[i]:
            print('fb error')
            error_fb = error_fb + 1
        if estimated_states[i] != hidden_states[i]:
            print('vi error')
            error_vi = error_fb + 1
        
    print('error_fb: ', error_fb, ' / ', len(hidden_states))
    print('error_vi: ', error_vi, ' / ', len(hidden_states))
    

    # if you haven't complete the algorithms, to use the visualization tool
    # let estimated_states = [None]*num_time_steps, marginals = [None]*num_time_steps
    # estimated_states = [None]*num_time_steps
    # marginals = [None]*num_time_steps
    if enable_graphics:
        app = graphics.playback_positions(hidden_states,
                                          observations,
                                          estimated_states,
                                          marginals)
        app.mainloop()
# Out:
# Running forward-backward...
#
#
# Most likely parts of marginal at time 0:
# [((10, 0, 'stay'), 0.8490566037735848), ((10, 1, 'stay'), 0.1509433962264151)]
#
#
# Most likely parts of marginal at time 1:
# [((10, 1, 'down'), 0.8490566037735848), ((10, 1, 'stay'), 0.15094339622641512)]
#
#
# Most likely parts of marginal at time 2:
# [((10, 2, 'down'), 1.0)]
#
#
# Most likely parts of marginal at time 3:
# [((10, 3, 'down'), 1.0)]
#
#
# Most likely parts of marginal at time 4:
# [((10, 4, 'down'), 1.0)]
#
#
# Most likely parts of marginal at time 5:
# [((10, 5, 'down'), 1.0)]
#
#
# Most likely parts of marginal at time 6:
# [((10, 6, 'down'), 1.0)]
#
#
# Most likely parts of marginal at time 7:
# [((10, 7, 'down'), 0.8509548206800186), ((10, 6, 'stay'), 0.1490451793199814)]
#
#
# Most likely parts of marginal at time 8:
# [((10, 7, 'stay'), 0.8509548206800187), ((10, 7, 'down'), 0.0745225896599907), ((11, 6, 'right'), 0.0745225896599907)]
#
#
# Most likely parts of marginal at time 9:
# [((10, 7, 'stay'), 0.9129017233348858), ((11, 6, 'stay'), 0.0745225896599907), ((10, 6, 'up'), 0.01257568700512343)]
#
#
# Most likely parts of marginal at time 10:
# [((10, 7, 'stay'), 0.8915055891942244), ((11, 6, 'stay'), 0.07277596646483468), ((10, 6, 'up'), 0.021396134140661393), ((10, 6, 'stay'), 0.012575687005123432), ((10, 6, 'left'), 0.0017466231951560325)]
#
#
# Most likely parts of marginal at time 11:
# [((11, 7, 'right'), 0.8915055891942244), ((11, 7, 'down'), 0.07277596646483468), ((10, 6, 'stay'), 0.035718444340940854)]
#
#
# Most likely parts of marginal at time 12:
# [((11, 7, 'stay'), 0.9642815556590592), ((10, 7, 'down'), 0.035718444340940854)]
#
#
# Most likely parts of marginal at time 13:
# [((10, 7, 'left'), 0.9642815556590592), ((10, 7, 'stay'), 0.03571844434094086)]
#
#
# Most likely parts of marginal at time 14:
# [((9, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 15:
# [((8, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 16:
# [((7, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 17:
# [((6, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 18:
# [((5, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 19:
# [((4, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 20:
# [((3, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 21:
# [((2, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 22:
# [((1, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 23:
# [((0, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 24:
# [((0, 7, 'stay'), 1.0)]
#
#
# Most likely parts of marginal at time 25:
# [((1, 7, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 26:
# [((2, 7, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 27:
# [((3, 7, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 28:
# [((4, 7, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 29:
# [((5, 7, 'right'), 0.9565217391304348), ((4, 7, 'stay'), 0.043478260869565216)]
#
#
# Most likely parts of marginal at time 30:
# [((6, 7, 'right'), 0.9130434782608695), ((5, 7, 'right'), 0.043478260869565216), ((5, 7, 'stay'), 0.043478260869565216)]
#
#
# Most likely parts of marginal at time 31:
# [((7, 7, 'right'), 0.8695652173913043), ((6, 7, 'right'), 0.08695652173913043), ((6, 7, 'stay'), 0.043478260869565216)]
#
#
# Most likely parts of marginal at time 32:
# [((8, 7, 'right'), 0.8260869565217391), ((7, 7, 'right'), 0.13043478260869568), ((7, 7, 'stay'), 0.04347826086956522)]
#
#
# Most likely parts of marginal at time 33:
# [((9, 7, 'right'), 0.782608695652174), ((8, 7, 'right'), 0.17391304347826086), ((8, 7, 'stay'), 0.043478260869565216)]
#
#
# Most likely parts of marginal at time 34:
# [((10, 7, 'right'), 0.7391304347826086), ((9, 7, 'right'), 0.21739130434782608), ((9, 7, 'stay'), 0.04347826086956522)]
#
#
# Most likely parts of marginal at time 35:
# [((11, 7, 'right'), 0.6956521739130435), ((10, 7, 'right'), 0.2608695652173913), ((10, 7, 'stay'), 0.04347826086956521)]
#
#
# Most likely parts of marginal at time 36:
# [((11, 7, 'stay'), 0.6956521739130435), ((11, 7, 'right'), 0.30434782608695643)]
#
#
# Most likely parts of marginal at time 37:
# [((11, 7, 'stay'), 1.0)]
#
#
# Most likely parts of marginal at time 38:
# [((11, 7, 'stay'), 1.0)]
#
#
# Most likely parts of marginal at time 39:
# [((11, 7, 'stay'), 0.8571428571428571), ((10, 7, 'left'), 0.14285714285714282)]
#
#
# Most likely parts of marginal at time 40:
# [((10, 7, 'left'), 0.8571428571428572), ((10, 7, 'stay'), 0.07142857142857144), ((9, 7, 'left'), 0.07142857142857141)]
#
#
# Most likely parts of marginal at time 41:
# [((9, 7, 'left'), 0.9285714285714286), ((9, 7, 'stay'), 0.07142857142857142)]
#
#
# Most likely parts of marginal at time 42:
# [((8, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 43:
# [((7, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 44:
# [((6, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 45:
# [((5, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 46:
# [((5, 7, 'stay'), 1.0)]
#
#
# Most likely parts of marginal at time 47:
# [((6, 7, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 48:
# [((7, 7, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 49:
# [((8, 7, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 50:
# [((9, 7, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 51:
# [((10, 7, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 52:
# [((11, 7, 'right'), 0.9967553536664503), ((10, 7, 'stay'), 0.0032446463335496427)]
#
#
# Most likely parts of marginal at time 53:
# [((11, 7, 'stay'), 0.9967553536664503), ((10, 7, 'stay'), 0.003244646333549643)]
#
#
# Most likely parts of marginal at time 54:
# [((10, 7, 'left'), 0.9967553536664505), ((10, 7, 'stay'), 0.0032446463335496435)]
#
#
# Most likely parts of marginal at time 55:
# [((9, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 56:
# [((8, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 57:
# [((7, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 58:
# [((6, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 59:
# [((5, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 60:
# [((4, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 61:
# [((4, 7, 'stay'), 1.0)]
#
#
# Most likely parts of marginal at time 62:
# [((4, 7, 'stay'), 1.0)]
#
#
# Most likely parts of marginal at time 63:
# [((3, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 64:
# [((3, 7, 'stay'), 0.5005322327309991), ((2, 7, 'left'), 0.499467767269001)]
#
#
# Most likely parts of marginal at time 65:
# [((2, 7, 'stay'), 0.499467767269001), ((3, 7, 'stay'), 0.47346666745026494), ((3, 6, 'up'), 0.027065565280734078)]
#
#
# Most likely parts of marginal at time 66:
# [((3, 7, 'right'), 0.499467767269001), ((3, 7, 'stay'), 0.4208478409396212), ((3, 6, 'up'), 0.052618826510643736), ((3, 6, 'stay'), 0.014717680659569686), ((3, 5, 'up'), 0.012347884621164401)]
#
#
# Most likely parts of marginal at time 67:
# [((3, 7, 'stay'), 0.8463203834280295), ((3, 6, 'up'), 0.07399522478059274), ((3, 5, 'up'), 0.03569505282847965), ((3, 6, 'stay'), 0.031641454341733766), ((3, 5, 'stay'), 0.0123478846211644)]
#
#
# Most likely parts of marginal at time 68:
# [((3, 6, 'up'), 0.8463203834280294), ((3, 5, 'up'), 0.05508314155222555), ((3, 6, 'stay'), 0.050553537570100955), ((3, 5, 'stay'), 0.03001221956533013), ((3, 4, 'up'), 0.01803071788431392)]
#
#
# Most likely parts of marginal at time 69:
# [((3, 5, 'up'), 0.8968739209981303), ((3, 5, 'stay'), 0.0545525683849099), ((3, 4, 'up'), 0.03054279273264579), ((3, 4, 'stay'), 0.01803071788431392)]
#
#
# Most likely parts of marginal at time 70:
# [((3, 4, 'up'), 0.9514264893830402), ((3, 4, 'stay'), 0.04857351061695971)]
#
#
# Most likely parts of marginal at time 71:
# [((3, 3, 'up'), 1.0)]
#
#
# Most likely parts of marginal at time 72:
# [((3, 3, 'stay'), 1.0)]
#
#
# Most likely parts of marginal at time 73:
# [((4, 3, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 74:
# [((5, 3, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 75:
# [((6, 3, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 76:
# [((7, 3, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 77:
# [((8, 3, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 78:
# [((9, 3, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 79:
# [((10, 3, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 80:
# [((11, 3, 'right'), 1.0)]
#
#
# Most likely parts of marginal at time 81:
# [((11, 3, 'stay'), 1.0)]
#
#
# Most likely parts of marginal at time 82:
# [((11, 2, 'up'), 1.0)]
#
#
# Most likely parts of marginal at time 83:
# [((11, 1, 'up'), 1.0)]
#
#
# Most likely parts of marginal at time 84:
# [((11, 0, 'up'), 0.9960371784710714), ((11, 1, 'stay'), 0.003962821528928598)]
#
#
# Most likely parts of marginal at time 85:
# [((11, 0, 'stay'), 0.9960371784710715), ((11, 1, 'stay'), 0.003602565026298726), ((11, 2, 'down'), 0.00036025650262987255)]
#
#
# Most likely parts of marginal at time 86:
# [((11, 1, 'down'), 0.9960371784710713), ((11, 1, 'stay'), 0.003242308523668853), ((11, 2, 'down'), 0.0003602565026298725), ((11, 2, 'stay'), 0.0003602565026298725)]
#
#
# Most likely parts of marginal at time 87:
# [((11, 2, 'down'), 0.9992794869947403), ((11, 2, 'stay'), 0.000720513005259745)]
#
#
# Most likely parts of marginal at time 88:
# [((11, 3, 'down'), 1.0)]
#
#
# Most likely parts of marginal at time 89:
# [((11, 4, 'down'), 1.0)]
#
#
# Most likely parts of marginal at time 90:
# [((11, 5, 'down'), 1.0)]
#
#
# Most likely parts of marginal at time 91:
# [((11, 6, 'down'), 1.0)]
#
#
# Most likely parts of marginal at time 92:
# [((11, 7, 'down'), 1.0)]
#
#
# Most likely parts of marginal at time 93:
# [((11, 7, 'stay'), 1.0)]
#
#
# Most likely parts of marginal at time 94:
# [((11, 7, 'stay'), 1.0)]
#
#
# Most likely parts of marginal at time 95:
# [((10, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 96:
# [((9, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 97:
# [((8, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 98:
# [((7, 7, 'left'), 1.0)]
#
#
# Most likely parts of marginal at time 99:
# [((6, 7, 'left'), 1.0)]
#
#
# Running Viterbi...
# C:\Users\www82\.conda\envs\MiaoPass\lib\site-packages\ipykernel_launcher.py:148: RuntimeWarning: divide by zero encountered in log
# Last 10 hidden states in the MAP estimate:
# (11, 5, 'down')
# (11, 6, 'down')
# (11, 7, 'down')
# (11, 7, 'stay')
# (11, 7, 'stay')
# (10, 7, 'left')
# (9, 7, 'left')
# (8, 7, 'left')
# (7, 7, 'left')
# (6, 7, 'left')
# Calculate error rate
# 0
# fb:(10, 0, 'stay')
# map:(10, 0, 'stay')
# real:(10, 0, 'stay')
# 1
# fb:(10, 1, 'down')
# map:(10, 1, 'down')
# real:(10, 1, 'down')
# 2
# fb:(10, 2, 'down')
# map:(10, 2, 'down')
# real:(10, 2, 'down')
# 3
# fb:(10, 3, 'down')
# map:(10, 3, 'down')
# real:(10, 3, 'down')
# 4
# fb:(10, 4, 'down')
# map:(10, 4, 'down')
# real:(10, 4, 'down')
# 5
# fb:(10, 5, 'down')
# map:(10, 5, 'down')
# real:(10, 5, 'down')
# 6
# fb:(10, 6, 'down')
# map:(10, 6, 'down')
# real:(10, 6, 'down')
# 7
# fb:(10, 7, 'down')
# map:(10, 7, 'down')
# real:(10, 7, 'down')
# 8
# fb:(10, 7, 'stay')
# map:(10, 7, 'stay')
# real:(10, 7, 'stay')
# 9
# fb:(10, 7, 'stay')
# map:(10, 7, 'stay')
# real:(10, 7, 'stay')
# 10
# fb:(10, 7, 'stay')
# map:(10, 7, 'stay')
# real:(10, 7, 'stay')
# 11
# fb:(11, 7, 'right')
# map:(11, 7, 'right')
# real:(11, 7, 'right')
# 12
# fb:(11, 7, 'stay')
# map:(11, 7, 'stay')
# real:(11, 7, 'stay')
# 13
# fb:(10, 7, 'left')
# map:(10, 7, 'left')
# real:(10, 7, 'left')
# 14
# fb:(9, 7, 'left')
# map:(9, 7, 'left')
# real:(9, 7, 'left')
# 15
# fb:(8, 7, 'left')
# map:(8, 7, 'left')
# real:(8, 7, 'left')
# 16
# fb:(7, 7, 'left')
# map:(7, 7, 'left')
# real:(7, 7, 'left')
# 17
# fb:(6, 7, 'left')
# map:(6, 7, 'left')
# real:(6, 7, 'left')
# 18
# fb:(5, 7, 'left')
# map:(5, 7, 'left')
# real:(5, 7, 'left')
# 19
# fb:(4, 7, 'left')
# map:(4, 7, 'left')
# real:(4, 7, 'left')
# 20
# fb:(3, 7, 'left')
# map:(3, 7, 'left')
# real:(3, 7, 'left')
# 21
# fb:(2, 7, 'left')
# map:(2, 7, 'left')
# real:(2, 7, 'left')
# 22
# fb:(1, 7, 'left')
# map:(1, 7, 'left')
# real:(1, 7, 'left')
# 23
# fb:(0, 7, 'left')
# map:(0, 7, 'left')
# real:(0, 7, 'left')
# 24
# fb:(0, 7, 'stay')
# map:(0, 7, 'stay')
# real:(0, 7, 'stay')
# 25
# fb:(1, 7, 'right')
# map:(1, 7, 'right')
# real:(1, 7, 'right')
# 26
# fb:(2, 7, 'right')
# map:(2, 7, 'right')
# real:(2, 7, 'right')
# 27
# fb:(3, 7, 'right')
# map:(3, 7, 'right')
# real:(3, 7, 'right')
# 28
# fb:(4, 7, 'right')
# map:(4, 7, 'right')
# real:(4, 7, 'right')
# 29
# fb:(5, 7, 'right')
# map:(5, 7, 'right')
# real:(5, 7, 'right')
# 30
# fb:(6, 7, 'right')
# map:(6, 7, 'right')
# real:(6, 7, 'right')
# 31
# fb:(7, 7, 'right')
# map:(7, 7, 'right')
# real:(7, 7, 'right')
# 32
# fb:(8, 7, 'right')
# map:(8, 7, 'right')
# real:(8, 7, 'right')
# 33
# fb:(9, 7, 'right')
# map:(9, 7, 'right')
# real:(9, 7, 'right')
# 34
# fb:(10, 7, 'right')
# map:(10, 7, 'right')
# real:(10, 7, 'right')
# 35
# fb:(11, 7, 'right')
# map:(11, 7, 'right')
# real:(11, 7, 'right')
# 36
# fb:(11, 7, 'stay')
# map:(11, 7, 'stay')
# real:(11, 7, 'stay')
# 37
# fb:(11, 7, 'stay')
# map:(11, 7, 'stay')
# real:(11, 7, 'stay')
# 38
# fb:(11, 7, 'stay')
# map:(11, 7, 'stay')
# real:(11, 7, 'stay')
# 39
# fb:(11, 7, 'stay')
# map:(11, 7, 'stay')
# real:(11, 7, 'stay')
# 40
# fb:(10, 7, 'left')
# map:(10, 7, 'left')
# real:(10, 7, 'left')
# 41
# fb:(9, 7, 'left')
# map:(9, 7, 'left')
# real:(9, 7, 'left')
# 42
# fb:(8, 7, 'left')
# map:(8, 7, 'left')
# real:(8, 7, 'left')
# 43
# fb:(7, 7, 'left')
# map:(7, 7, 'left')
# real:(7, 7, 'left')
# 44
# fb:(6, 7, 'left')
# map:(6, 7, 'left')
# real:(6, 7, 'left')
# 45
# fb:(5, 7, 'left')
# map:(5, 7, 'left')
# real:(5, 7, 'left')
# 46
# fb:(5, 7, 'stay')
# map:(5, 7, 'stay')
# real:(5, 7, 'stay')
# 47
# fb:(6, 7, 'right')
# map:(6, 7, 'right')
# real:(6, 7, 'right')
# 48
# fb:(7, 7, 'right')
# map:(7, 7, 'right')
# real:(7, 7, 'right')
# 49
# fb:(8, 7, 'right')
# map:(8, 7, 'right')
# real:(8, 7, 'right')
# 50
# fb:(9, 7, 'right')
# map:(9, 7, 'right')
# real:(9, 7, 'right')
# 51
# fb:(10, 7, 'right')
# map:(10, 7, 'right')
# real:(10, 7, 'right')
# 52
# fb:(11, 7, 'right')
# map:(11, 7, 'right')
# real:(11, 7, 'right')
# 53
# fb:(11, 7, 'stay')
# map:(11, 7, 'stay')
# real:(11, 7, 'stay')
# 54
# fb:(10, 7, 'left')
# map:(10, 7, 'left')
# real:(10, 7, 'left')
# 55
# fb:(9, 7, 'left')
# map:(9, 7, 'left')
# real:(9, 7, 'left')
# 56
# fb:(8, 7, 'left')
# map:(8, 7, 'left')
# real:(8, 7, 'left')
# 57
# fb:(7, 7, 'left')
# map:(7, 7, 'left')
# real:(7, 7, 'left')
# 58
# fb:(6, 7, 'left')
# map:(6, 7, 'left')
# real:(6, 7, 'left')
# 59
# fb:(5, 7, 'left')
# map:(5, 7, 'left')
# real:(5, 7, 'left')
# 60
# fb:(4, 7, 'left')
# map:(4, 7, 'left')
# real:(4, 7, 'left')
# 61
# fb:(4, 7, 'stay')
# map:(4, 7, 'stay')
# real:(4, 7, 'stay')
# 62
# fb:(4, 7, 'stay')
# map:(4, 7, 'stay')
# real:(4, 7, 'stay')
# 63
# fb:(3, 7, 'left')
# map:(3, 7, 'left')
# real:(3, 7, 'left')
# 64
# fb:(3, 7, 'stay')
# map:(2, 7, 'left')
# real:(3, 7, 'stay')
# vi error
# 65
# fb:(2, 7, 'stay')
# map:(2, 7, 'stay')
# real:(3, 7, 'stay')
# fb error
# vi error
# 66
# fb:(3, 7, 'right')
# map:(3, 7, 'right')
# real:(3, 7, 'stay')
# fb error
# vi error
# 67
# fb:(3, 7, 'stay')
# map:(3, 7, 'stay')
# real:(3, 7, 'stay')
# 68
# fb:(3, 6, 'up')
# map:(3, 6, 'up')
# real:(3, 6, 'up')
# 69
# fb:(3, 5, 'up')
# map:(3, 5, 'up')
# real:(3, 5, 'up')
# 70
# fb:(3, 4, 'up')
# map:(3, 4, 'up')
# real:(3, 4, 'up')
# 71
# fb:(3, 3, 'up')
# map:(3, 3, 'up')
# real:(3, 3, 'up')
# 72
# fb:(3, 3, 'stay')
# map:(3, 3, 'stay')
# real:(3, 3, 'stay')
# 73
# fb:(4, 3, 'right')
# map:(4, 3, 'right')
# real:(4, 3, 'right')
# 74
# fb:(5, 3, 'right')
# map:(5, 3, 'right')
# real:(5, 3, 'right')
# 75
# fb:(6, 3, 'right')
# map:(6, 3, 'right')
# real:(6, 3, 'right')
# 76
# fb:(7, 3, 'right')
# map:(7, 3, 'right')
# real:(7, 3, 'right')
# 77
# fb:(8, 3, 'right')
# map:(8, 3, 'right')
# real:(8, 3, 'right')
# 78
# fb:(9, 3, 'right')
# map:(9, 3, 'right')
# real:(9, 3, 'right')
# 79
# fb:(10, 3, 'right')
# map:(10, 3, 'right')
# real:(10, 3, 'right')
# 80
# fb:(11, 3, 'right')
# map:(11, 3, 'right')
# real:(11, 3, 'right')
# 81
# fb:(11, 3, 'stay')
# map:(11, 3, 'stay')
# real:(11, 3, 'stay')
# 82
# fb:(11, 2, 'up')
# map:(11, 2, 'up')
# real:(11, 2, 'up')
# 83
# fb:(11, 1, 'up')
# map:(11, 1, 'up')
# real:(11, 1, 'up')
# 84
# fb:(11, 0, 'up')
# map:(11, 0, 'up')
# real:(11, 0, 'up')
# 85
# fb:(11, 0, 'stay')
# map:(11, 0, 'stay')
# real:(11, 0, 'stay')
# 86
# fb:(11, 1, 'down')
# map:(11, 1, 'down')
# real:(11, 1, 'down')
# 87
# fb:(11, 2, 'down')
# map:(11, 2, 'down')
# real:(11, 2, 'down')
# 88
# fb:(11, 3, 'down')
# map:(11, 3, 'down')
# real:(11, 3, 'down')
# 89
# fb:(11, 4, 'down')
# map:(11, 4, 'down')
# real:(11, 4, 'down')
# 90
# fb:(11, 5, 'down')
# map:(11, 5, 'down')
# real:(11, 5, 'down')
# 91
# fb:(11, 6, 'down')
# map:(11, 6, 'down')
# real:(11, 6, 'down')
# 92
# fb:(11, 7, 'down')
# map:(11, 7, 'down')
# real:(11, 7, 'down')
# 93
# fb:(11, 7, 'stay')
# map:(11, 7, 'stay')
# real:(11, 7, 'stay')
# 94
# fb:(11, 7, 'stay')
# map:(11, 7, 'stay')
# real:(11, 7, 'stay')
# 95
# fb:(10, 7, 'left')
# map:(10, 7, 'left')
# real:(10, 7, 'left')
# 96
# fb:(9, 7, 'left')
# map:(9, 7, 'left')
# real:(9, 7, 'left')
# 97
# fb:(8, 7, 'left')
# map:(8, 7, 'left')
# real:(8, 7, 'left')
# 98
# fb:(7, 7, 'left')
# map:(7, 7, 'left')
# real:(7, 7, 'left')
# 99
# fb:(6, 7, 'left')
# map:(6, 7, 'left')
# real:(6, 7, 'left')
# error_fb:  2  /  100
# error_vi:  3  /  100
